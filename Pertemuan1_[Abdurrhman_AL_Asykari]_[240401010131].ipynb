# %% [markdown]
# <a href="https://colab.research.google.com/github/GulaiRandang/Data-Science_IF405_2026/blob/main/Pertemuan1_%5BAbdurrhman_AL_Asykari%5D_%5B240401010131%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# latihan 1

# %%
#Output sederhana
print("hello UNSIA")

# %%
#Variable & Data types
nama ="Abdurrahman Al Asykari" #string
prodi ="Informatika"
angkatan = 2024 #numeric
NIM = 240401010131

print(nama)
print(angkatan)
print(f"Halo nama saya {nama} dari prodi {prodi} angkatan {angkatan} dengan NIM {NIM}")
# Out:
# Abdurrahman Al Asykari
# 2026
# Halo nama saya Abdurrahman Al Asykari dari prodi Informatika angkatan 2026 dengan NIM 240401010131

# %%
#list
tools = ["Python", "Google colab", "Jupiter notebaook", "Github"]
for i in tools:
  print(i)
# Out:
# Python
# Google colab
# Jupiter notebaook
# Github

# %%
#Fungsi
def perkenalan(nama, prodi, angkaran):
  return print (f"Halo nama saya {nama} dari prodi {prodi} angkatan {angkatan} dengan NIM {NIM}")

perkenalan ("Askar", "Informatika", 2024)
# Out:
# Halo nama saya Askar dari prodi Informatika angkatan 2026 dengan NIM 240401010131
